# %% [markdown]
# # BLOQUE 01 – Movilidad activa
# ## Objetivo
# Construir capa consolidada demográfica normalizada por unidad espacial.
# ## Inputs
# - ciclovias.shp
# - estaciones.shp
# ## Procesos
# - Limpieza
# - Homologación de CRS
# - Join espacial
# - Normalización
# ## Output
# 1_D4C1V1_ciclovias.gpkg
# - 1_D4C1V1_ciclovias.shp
# - 1_D4C1V1_estaciones_mibici.shp

# %%
import geopandas as gpd
import pandas as pd
import os

# %%
# Rutas alex
ruta_ciclovias = r"C:\Users\alflo\Desktop\DAL_LAB\data_raw\Mi Bici y Ciclovía\Ciclovías.gpkg"
ruta_estaciones = r"C:\Users\alflo\Desktop\DAL_LAB\data_raw\Mi Bici y Ciclovía\Estaciones Mi Bici.gpkg"

ruta_salida = r"C:\Users\alflo\Desktop\DAL_LAB\outputs\etapa_1\1_D4C1_Movilidad.gpkg"

# #rutas aldo
# ruta_ciclovias = r"C:\Users\aldov\OneDrive\Escritorio\DAL_LABORATY\data_raw\Mi Bici y Ciclovía\Ciclovías.gpkg"
# ruta_estaciones = r"C:\Users\aldov\OneDrive\Escritorio\DAL_LABORATY\data_raw\Mi Bici y Ciclovía\Estaciones Mi Bici.gpkg"
# ruta_salida = r"C:\Users\aldov\OneDrive\Escritorio\DAL_LABORATY\outputs\1_D4C1_Movilidad.gpkg"

# %% [markdown]
# # Ciclovías

# %%
# --- 2. PROCESAMIENTO DE CICLOVÍAS ---
gdf_ciclo = gpd.read_file(ruta_ciclovias)

# Añadir columna categoría
gdf_ciclo['Categoría'] = 'ciclovía'

# Borrar columnas específicas
cols_a_borrar_ciclo = ["ano_de_rec", "ano_de_con", "kilometros", "tipo_de_ci"]

gdf_ciclo = gdf_ciclo.drop(columns=cols_a_borrar_ciclo, errors='ignore')

# Guardar en la ruta especificada
gdf_ciclo.to_file(ruta_salida, layer='1_D4C1V1_ciclovias', driver="GPKG")

# %% [markdown]
# # Estaciones

# %%
# --- 3. PROCESAMIENTO DE ESTACIONES MI BICI ---
gdf_estaciones = gpd.read_file(ruta_estaciones)

# Añadir columna categoría
gdf_estaciones['Categoría'] = 'estación_mi_bici'

# Borrar columna específica
gdf_estaciones = gdf_estaciones.drop(columns=["municipio", "nombre_de_"], errors='ignore')

# Guardar en la ruta especificada
gdf_estaciones.to_file(ruta_salida, layer='1_D4C1V1_estaciones_mibici', driver="GPKG")
