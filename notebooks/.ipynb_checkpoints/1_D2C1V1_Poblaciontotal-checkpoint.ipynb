# %% [markdown]
# # BLOQUE 01 – PERFIL DEMOGRÁFICO
# ## Objetivo
# Construir capa consolidada demográfica normalizada por unidad espacial.
# ## Inputs
# - poblacion.shp
# - genero.shp
# - discapacidad.csv
# ## Procesos
# - Limpieza
# - Homologación de CRS
# - Join espacial
# - Normalización
# 1_D2C1V1_output_Poblaciontotal.gpkgerfdem_v01.shp

# %%
import pandas as pd

# Cargar el archivo
# Asegúrate de que el archivo esté en la misma carpeta que tu notebook
df = pd.read_excel(r"C:\Users\Alejandro\Documents\GitHub\DAL-LABORATORY\data_raw\demográfico\RESAGEBURB_14XLSX20.xlsx")

# Obtener el número de columnas
num_columnas = df.shape[1]

print(f"El archivo tiene {num_columnas} columnas.")

"C:\Users\Alejandro\Documents\GitHub\DAL-LABORATORY\outputs\etapa 1\README.md"
# Out:
# El archivo tiene 231 columnas.

# %% [markdown]
# - Hecho en qgis
#
# - limpie
#
# - cponspoñe
#
# ss
#
# s
# s
