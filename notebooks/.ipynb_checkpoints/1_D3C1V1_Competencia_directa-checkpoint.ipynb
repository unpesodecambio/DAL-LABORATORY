# %% [markdown]
# # BLOQUE 01 – PERFIL ECONOMICO
# ## Objetivo
# Construir capa consolidada ECONOMICA normalizada por unidad espacial.
# ## Inputs
# - denue.shp
# - manzana.shp
#
# ## Procesos
# - Limpieza
# - Homologación de CRS
# - Join espacial
# - Normalización
#
# ## Output
# 1_D3C1V1_output_1_Competencia_directa.shp

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Polygon
from dbfread import DBF
import jenkspy
import json
from jenkspy import jenks_breaks
import time

# %%
# Rutas
estaciones mibici = r"C:\Users\Alejandro\Desktop\DAL_LAB\data_raw\DENUE\denue_inegi_14_.shp"
estaciones TP = r"C:\Users\Alejandro\Desktop\DAL LAB\data_raw\Manzanas\14m.shp"

CV = r"C:\Users\Alejandro\Desktop\DAL_LAB\data_raw\DENUE\denue_inegi_14_.shp"
masivo = r"C:\Users\Alejandro\Desktop\DAL LAB\data_raw\Manzanas\14m.shp"
colectivo = r"C:\Users\Alejandro\Desktop\DAL LAB\data_raw\Manzanas\14m.shp"

Vialidad = r"C:\Users\Alejandro\Desktop\DAL LAB\data_raw\Manzanas\14m.shp"



ruta_salida = r"C:\Users\Alejandro\Desktop\DAL_LAB\outputs\etapa_1\1_D2C1_output_1_Población.gpkg"

# %%
# Cargar los GeoDataFrames
gdf_denue = gpd.read_file(DENUE_ruta)
gdf_manzanas = gpd.read_file(manzanas_ruta)
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Cargar los GeoDataFrames
#       2 gdf_denue = gpd.read_file(DENUE_ruta)
# ----> 3 gdf_manzanas = gpd.read_file(manzanas_ruta)
#
# File ~\anaconda3\Lib\site-packages\geopandas\io\file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296     )
#     298 elif engine == "fiona":
#     299     if pd.api.types.is_file_like(filename):
#
# File ~\anaconda3\Lib\site-packages\geopandas\io\file.py:547, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     538     warnings.warn(
# ...

# %%
#Campo empleados

# Definir la función de conversión
def convert_per_ocu_to_value(per_ocu):
    mapping = {
        '0 a 5 personas': 3,
        '6 a 10 personas': 8,
        '11 a 30 personas': 20,
        '31 a 50 personas': 40,
        '51 a 100 personas': 75,
        '101 a 250 personas': 175,
        '251 y más personas': 275
    }
    return mapping.get(per_ocu, None)

# Aplicar la función para crear la nueva columna
gdf_manzanas['Num_Emp'] = SHP_DENUE_2020_gdf['per_ocu'].apply(convert_per_ocu_to_value)

# %%
##########LEER GPKG MANZANAS PARA CONTEO

# Cargar los GeoDataFrames de las manzanas y las unidades económicas
gdf_manzanas = gpd.read_file('ruta/a/tu/archivo/manzanas.shp')

SHP_DENUE_2020_gdf = gpd.read_file(r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE.gpkg", layer='2020')


# Crear un buffer de 10 metros alrededor de las manzanas
gdf_manzanas_buffer = gdf_manzanas.copy()
gdf_manzanas_buffer['geometry'] = gdf_manzanas_buffer.geometry.buffer(10)

# Realizar la unión espacial entre las manzanas y las unidades económicas
gdf_union = gpd.sjoin(gdf_manzanas_buffer, SHP_DENUE_2010_gdf, how="left", op="contains")

# Contar el número de unidades económicas dentro de cada manzana
numero_unidades_por_manzana = gdf_union.groupby('ID_MANZANA').size().reset_index(name='UE_10')

# Sumar el número de empleados de las unidades económicas dentro de cada manzana
sum_empleados_por_manzana = gdf_union.groupby('ID_MANZANA')['Num_Emp'].sum().reset_index(name='Emp_10')

# Unir los resultados al GeoDataFrame de las manzanas
gdf_manzanas_final = gdf_manzanas.merge(numero_unidades_por_manzana, on='ID_MANZANA', how='left')
gdf_manzanas_final = gdf_manzanas_final.merge(sum_empleados_por_manzana, on='ID_MANZANA', how='left')

# Mostrar el resultado
print(gdf_manzanas_final)

# %%
# Guardar el GeoPackage con los nuevos campos
gdf_manzanas_poblacion.to_file(ruta_salida, layer='1_D2C1V1_Población_total_objetivo', driver='GPKG')

gdf_manzanas_condicionantes.to_file(ruta_salida, layer='1_D2C1V2_Condicionantes', driver='GPKG')

gdf_manzanas_condicionantes.to_file(ruta_salida, layer='1_D2C1V2_Condicionantes', driver='GPKG')

gdf_manzanas_condicionantes.to_file(ruta_salida, layer='1_D2C1V2_Condicionantes', driver='GPKG')
